# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading data

# %%
crime_data=pd.read_csv("C:\\Users\\Govind S\\Downloads\\ds\\ds files\\assignments\\clustering\\crime_data.csv")

# %%
crime_data
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %% [markdown]
# ### Removing columns not needed for clustering

# %%
crime_data_mod=crime_data.iloc[:,1:]

# %%
crime_data_mod
# Out:
#     Murder  Assault  UrbanPop  Rape
# 0     13.2      236        58  21.2
# 1     10.0      263        48  44.5
# 2      8.1      294        80  31.0
# 3      8.8      190        50  19.5
# 4      9.0      276        91  40.6
# 5      7.9      204        78  38.7
# 6      3.3      110        77  11.1
# 7      5.9      238        72  15.8
# 8     15.4      335        80  31.9
# 9     17.4      211        60  25.8
# 10     5.3       46        83  20.2
# 11     2.6      120        54  14.2
# 12    10.4      249        83  24.0
# 13     7.2      113        65  21.0
# 14     2.2       56        57  11.3
# 15     6.0      115        66  18.0
# 16     9.7      109        52  16.3
# 17    15.4      249        66  22.2
# 18     2.1       83        51   7.8
# 19    11.3      300        67  27.8
# 20     4.4      149        85  16.3
# 21    12.1      255        74  35.1
# 22     2.7       72        66  14.9
# 23    16.1      259        44  17.1
# 24     9.0      178        70  28.2
# ...

# %%
ss=StandardScaler()
x=ss.fit_transform(crime_data_mod)

# %% [markdown]
# ## Hierarchial Clustering

# %% [markdown]
# ### Dendogram

# %%
dendrogram = sch.dendrogram(sch.linkage(x, method='complete'))

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'complete')
a=hc.fit_predict(x)
crime_data['cluster_id_hc']=pd.Series(a)
crime_data.cluster_id_hc.value_counts()
# Out:
# 0    31
# 2    11
# 1     8
# Name: cluster_id_hc, dtype: int64

# %%
crime_data.groupby('cluster_id_hc').mean()
# Out:
#                   Murder     Assault   UrbanPop       Rape
# cluster_id_hc
# 0               5.003226  116.483871  63.838710  16.338710
# 1              14.087500  252.750000  53.500000  24.537500
# 2              11.054545  264.090909  79.090909  32.618182

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'complete')
a=hc.fit_predict(x)
crime_data['cluster_id_hc']=pd.Series(a)
crime_data.cluster_id_hc.value_counts()
# Out:
# 1    21
# 2    11
# 3    10
# 0     8
# Name: cluster_id_hc, dtype: int64

# %%
crime_data.groupby('cluster_id_hc').mean()
# Out:
#                   Murder     Assault   UrbanPop       Rape
# cluster_id_hc
# 0              14.087500  252.750000  53.500000  24.537500
# 1               5.871429  134.476190  70.761905  18.580952
# 2              11.054545  264.090909  79.090909  32.618182
# 3               3.180000   78.700000  49.300000  11.630000

# %%
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'complete')
a=hc.fit_predict(x)
crime_data['cluster_id_hc']=pd.Series(a)
crime_data.cluster_id_hc.value_counts()
# Out:
# 0    21
# 2    11
# 3    10
# 1     7
# 4     1
# Name: cluster_id_hc, dtype: int64

# %%
crime_data.groupby('cluster_id_hc').mean()
# Out:
#                   Murder     Assault   UrbanPop       Rape
# cluster_id_hc
# 0               5.871429  134.476190  70.761905  18.580952
# 1              14.671429  251.285714  54.285714  21.685714
# 2              11.054545  264.090909  79.090909  32.618182
# 3               3.180000   78.700000  49.300000  11.630000
# 4              10.000000  263.000000  48.000000  44.500000

# %% [markdown]
# ### Clustering into 4 clusters give the best results

# %% [markdown]
# ## K means clustering

# %% [markdown]
# ### Elbow graph

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

print(wcss)    
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')

plt.grid()
plt.show()
# Out:
# [200.0, 104.96163315756871, 80.0888613219962, 57.55425863091104, 50.520265525350695, 43.927464044975736, 40.521834611319754, 34.6873883978491, 32.70648136388184, 28.311639397122555]

# %% [markdown]
# ### From the elbow graph the inertia increase reduce after 4 clusters

# %%
    kmeans = KMeans(n_clusters=4,random_state=0)
    kmeans.fit(x)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
kmeans.labels_
# Out:
# array([3, 1, 1, 3, 1, 1, 0, 0, 1, 3, 0, 2, 1, 0, 2, 0, 2, 3, 2, 1, 0, 1,
#        2, 3, 1, 2, 2, 1, 2, 0, 1, 1, 3, 2, 0, 0, 0, 0, 0, 3, 2, 3, 1, 0,
#        2, 0, 0, 2, 2, 0])

# %%
crime_data['cluster_id_kmeans']=kmeans.labels_

# %%
crime_data.groupby('cluster_id_kmeans').mean()
# Out:
#                       Murder     Assault   UrbanPop       Rape  cluster_id_hc
# cluster_id_kmeans
# 0                   5.656250  138.875000  73.875000  18.781250       0.000000
# 1                  10.815385  257.384615  76.000000  33.192308       2.000000
# 2                   3.600000   78.538462  52.076923  12.176923       2.307692
# 3                  13.937500  243.625000  53.750000  21.412500       0.875000

# %% [markdown]
# ### There is reasonable difference between the clusters

# %% [markdown]
# ## DBSCAN

# %%
dbscan = DBSCAN(eps=1.0, min_samples=8)
dbscan.fit(x)
# Out:
# DBSCAN(eps=1.0, min_samples=8)

# %%
crime_data['cluster_id_db']=pd.Series(dbscan.labels_)

# %%
crime_data.cluster_id_db.value_counts()
# Out:
# -1    32
#  0    18
# Name: cluster_id_db, dtype: int64

# %%
def dbscan(X,eps,min_samples):
    db=DBSCAN(eps=eps,min_samples=min_samples)
    db.fit(X)
    y_pred=db.fit_predict(X)
    s=metrics.silhouette_score(x,db.labels_)
    plt.scatter(X[:,0],X[:,1],c=y_pred, cmap='Paired')
    plt.title("DBSCAN")

# %%
dbscan(x,1,8)

# %%
crime_data.groupby('cluster_id_db').mean().iloc[:,:4]
# Out:
#                  Murder     Assault   UrbanPop       Rape
# cluster_id_db
# -1             9.609375  209.000000  68.156250  24.446875
#  0             4.550000  102.777778  60.888889  15.516667

# %% [markdown]
# ### With DBSCAN best results are achieved with clustering into 2 clusters including outliers

# %% [markdown]
# ### With hierarchical and kmeans clustering the best results were achieved with 4 clusters
